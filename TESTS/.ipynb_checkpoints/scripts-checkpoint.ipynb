# %% [markdown]
# # SCRIPTS
#
# 1. Partitions the images/xmls intro train and test dataset.
# 2. Convert xmls to tfrecords
# 3. XML changer for testing (-optional)
# 4. Inspecting TFrecord for testing (-optional)
# 5. Training
# 6. Model Evaluation
# 7. Exporting Model
# '''

# %%
#https://tensorflow-object-detection-api-tutorial.readthedocs.io/en/latest/training.html#preparing-the-workspace
import tensorflow as tf
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"

#print(tf.__version__)
tf.config.list_physical_devices('GPU')

# %% [markdown]
# # Partioning Images into Train and Test Dataset

# %%
# Imports

import os
import re
from shutil import copyfile
import argparse
import math
import random

# Partition images

def partition_images(source, dest, ratio=0.1, copy_xml=True):
    copy_xml = True
    source = source
    dest = dest
    train_dir = os.path.join(dest, 'train')
    test_dir = os.path.join(dest, 'test')

    if not os.path.exists(train_dir):
        os.makedirs(train_dir)
    if not os.path.exists(test_dir):
        os.makedirs(test_dir)

    images = [f for f in os.listdir(source)
              if re.search(r'([a-zA-Z0-9\s_\\.\-\(\):])+(.jpg|.jpeg|.png)$', f)]

    num_images = len(images)
    num_test_images = math.ceil(ratio*num_images)

    for i in range(num_test_images):
        idx = random.randint(0, len(images)-1)
        filename = images[idx]
        copyfile(os.path.join(source, filename),
                 os.path.join(test_dir, filename))
        if copy_xml:
            xml_filename = os.path.splitext(filename)[0]+'.xml'
            copyfile(os.path.join(source, xml_filename),
                     os.path.join(test_dir,xml_filename))
        images.remove(images[idx])

    for filename in images:
        copyfile(os.path.join(source, filename),
                 os.path.join(train_dir, filename))
        if copy_xml:
            xml_filename = os.path.splitext(filename)[0]+'.xml'
            copyfile(os.path.join(source, xml_filename),
                     os.path.join(train_dir, xml_filename))

#partition_images()

# %% [markdown]
# # Convert Labels to .tfrecords

# %%
import os
import glob
import pandas as pd
import io
import xml.etree.ElementTree as ET

import tensorflow.compat.v1 as tf
from PIL import Image
from object_detection.utils import dataset_util, label_map_util
from collections import namedtuple

label_map_dict = {'line': 1}

def label_def(labels_path):
    label_map = label_map_util.load_labelmap(labels_path)
    label_map_dict = label_map_util.get_label_map_dict(label_map)
    #print("label_map_dict", label_map_dict)


def xml_to_csv(path):
    xml_list = []
    for xml_file in glob.glob(path + '/*.xml'):
        tree = ET.parse(xml_file)
        root = tree.getroot()
        #print(root.findall('_object'))
        for member in root.findall('_object'):
            value = (root.find('filename').text,
                     int(float(root.find('size')[0].text)),
                     int(float(root.find('size')[1].text)),
                     member[0].text,
                     float(member[4][0].text),
                     float(member[4][1].text),
                     float(member[4][2].text),
                     float(member[4][3].text)
                     )
            xml_list.append(value)
    column_name = ['filename', 'width', 'height',
                   'class', 'xmin', 'ymin', 'xmax', 'ymax']
    xml_df = pd.DataFrame(xml_list, columns=column_name)
    return xml_df


def class_text_to_int(row_label):
    
    return label_map_dict[row_label]


def split(df, group):
    data = namedtuple('data', ['filename', 'object'])
    gb = df.groupby(group)
    return [data(filename, gb.get_group(x)) for filename, x in zip(gb.groups.keys(), gb.groups)]


def create_tf_example(group, path):
    with tf.gfile.GFile(os.path.join(path, '{}'.format(group.filename)), 'rb') as fid:
        #print(fid.read())
        encoded_jpg = fid.read()
    encoded_jpg_io = io.BytesIO(encoded_jpg)
    image = Image.open(encoded_jpg_io)
    width, height = image.size

    filename = group.filename.encode('utf8')
    image_format = b'jpg'
    xmins = []
    xmaxs = []
    ymins = []
    ymaxs = []
    classes_text = []
    classes = []
    
    for index, row in group.object.iterrows():
        print("---------------", index, "----------------")
              
        ########### ADDITIONAL CHECKS START HERE ###################

        corrected_xmax = max(row['xmin']/ width, row['xmax']/ width)
        corrected_xmin = min(row['xmin']/ width, row['xmax']/ width)
        corrected_ymax = max(row['ymin']/ height, row['ymax']/ height)
        corrected_ymin = min(row['ymin']/ height, row['ymax']/ height)
        
        print("CORRECTS", corrected_xmax, corrected_xmin, corrected_ymax, corrected_ymin)
        
        xmn = corrected_xmin
        if xmn < 0.0:
            xmn = 0.0
        elif xmn > 1.0:
            xmn = 1.0
        xmins.append(xmn)

        xmx = corrected_xmax
        if xmx < 0.0:
            xmx = 0.0
        elif xmx > 1.0:
            xmx = 1.0
        xmaxs.append(xmx)

        ymn = corrected_ymin
        if ymn < 0.0:
            ymn = 0.0
        elif ymn > 1.0:
            ymn = 1.0
        ymins.append(ymn)

        ymx = corrected_ymax
        if ymx < 0.0:
            ymx = 0.0
        elif ymx > 1.0:
            ymx = 1.0
        ymaxs.append(ymx)

        ############ ADDITIONAL CHECKS END HERE ####################
        classes_text.append(row['class'].encode('utf8'))
        classes.append(class_text_to_int(row['class']))
    '''
    for index, row in group.object.iterrows():
        xmins.append(row['xmin'] / width)
        xmaxs.append(row['xmax'] / width)
        ymins.append(row['ymin'] / height)
        ymaxs.append(row['ymax'] / height)
        classes_text.append(row['class'].encode('utf8'))
        classes.append(class_text_to_int(row['class']))
    '''
    tf_example = tf.train.Example(features=tf.train.Features(feature={
        'image/height': dataset_util.int64_feature(height),
        'image/width': dataset_util.int64_feature(width),
        'image/filename': dataset_util.bytes_feature(filename),
        'image/source_id': dataset_util.bytes_feature(filename),
        'image/encoded': dataset_util.bytes_feature(encoded_jpg),
        'image/format': dataset_util.bytes_feature(image_format),
        'image/object/bbox/xmin': dataset_util.float_list_feature(xmins),
        'image/object/bbox/xmax': dataset_util.float_list_feature(xmaxs),
        'image/object/bbox/ymin': dataset_util.float_list_feature(ymins),
        'image/object/bbox/ymax': dataset_util.float_list_feature(ymaxs),
        'image/object/class/text': dataset_util.bytes_list_feature(classes_text),
        'image/object/class/label': dataset_util.int64_list_feature(classes),
    }))
    return tf_example

def run_this():
    #definitions
    xml_dir = "../../custom/test"
    image_dir = xml_dir
    output_path = "../../custom/test.record"
    csv_path = "../../custom/test_labels.csv"
    label_path = "../../custom/label_map.pbtxt"
    
    label_def(label_path)
    writer = tf.python_io.TFRecordWriter(output_path)
    path = os.path.join(image_dir)
    examples = xml_to_csv(xml_dir)
    grouped = split(examples, 'filename')
    for group in grouped:
        tf_example = create_tf_example(group, path)
        writer.write(tf_example.SerializeToString())
    writer.close()
    print('Successfully created the TFRecord file: {}'.format(output_path))
    if csv_path is not None:
        examples.to_csv(csv_path, index=None)
        print('Successfully created the CSV file: {}'.format(csv_path))
        
#run_this()
# Out:
# --------------- 21 ----------------
# CORRECTS 0.0022058819942951014 0.0004624410195721689 0.0013301639812100623 0.0012779442206008454
# --------------- 18 ----------------
# CORRECTS 0.0022498078395079423 0.0014373454797193769 0.0031988120450978123 0.0011486870270477738
# --------------- 44 ----------------
# CORRECTS 0.0016711878133284423 0.0016356901718917226 0.002944063147621437 0.0002846245996420088
# --------------- 25 ----------------
# CORRECTS 0.002215109556528284 0.0004721285050017389 0.0008446566168316725 0.0005470863684735286
# --------------- 48 ----------------
# CORRECTS 0.0011988810851560371 0.0009119457014603792 0.0017888204958379996 0.0011648324424587972
# --------------- 41 ----------------
# CORRECTS 0.0016839453767291536 0.001149891505285411 0.00027146668018172257 0.000241693144039161
# --------------- 42 ----------------
# CORRECTS 0.001894577513624566 0.0013895899478784583 0.0030558162547134993 0.0012349480933963558
# --------------- 13 ----------------
# CORRECTS 0.002068753270913969 0.000242249057535566 0.003414115085637366 0.0013148918985682215
# --------------- 24 ----------------
# CORRECTS 0.0012846588665834445 0.0006903298578736929 0.002907277514689414 0.0011401995346963195
# --------------- 35 ----------------
# CORRECTS 0.0008637311162658221 0.0005969747784428306 0.0024525128433812906 0.0014351875033502628
# --------------- 43 ----------------
# CORRECTS 0.0020076718339050803 0.00046184380751297996 0.0018394596249691256 0.001276370061812508
# --------------- 14 ----------------
# CORRECTS 0.0006092177054355429 0.0005071349083684015 0.0019280624958909484 0.001297582812476144
# --------------- 23 ----------------
# CORRECTS 0.0008917556389031821 0.0001640243347841076 0.0014162356415180618 4.057814430795894e-05
# --------------- 45 ----------------
# CORRECTS 0.0018511394058007959 0.00043926621537751997 0.001223947774963506 0.0005955014188050935
# --------------- 19 ----------------
# CORRECTS 0.0021320379743290842 2.2963638446450872e-05 0.0030109455673944623 0.0026842483200615907
# --------------- 22 ----------------
# CORRECTS 0.001957567009378217 0.0013236974922928848 0.002878514136878306 0.00039854934163026227
# --------------- 16 ----------------
# CORRECTS 0.0004059868835419735 0.00013846458349836015 0.0016694222182312343 0.0013008166738049482
# CORRECTS 0.0013551520558288189 0.0009648443787782188 0.0032240170699720377 0.0009198384939519076
# --------------- 36 ----------------
# CORRECTS 0.0018084127775893437 0.0014125665817150042 0.0015047555990069393 0.0009159734430310722
# --------------- 7 ----------------
# CORRECTS 0.0017111891912498659 0.0003939069468811657 0.003260501898776155 0.002311370336411095
# --------------- 6 ----------------
# CORRECTS 0.0020563843282504313 0.00035114443083139835 0.003247072922944371 0.0018757885786973997
# --------------- 46 ----------------
# CORRECTS 0.001999825003498294 0.00047036767116878474 0.0012835109530321468 0.00033807965188679685
# --------------- 3 ----------------
# CORRECTS 0.0023133774448577302 0.0016305147699853975 0.0015984351931519454 0.0012707532547827911
# --------------- 2 ----------------
# CORRECTS 0.0019133202974626372 0.0011534963409058684 0.0004596056597026693 0.0003349027529700204
# --------------- 20 ----------------
# CORRECTS 0.0019055903575777371 0.0011252629235834655 0.0012327265657989482 0.0007833193384331302
# Successfully created the TFRecord file: ../../custom/test.record
# Successfully created the CSV file: ../../custom/test_labels.csv

# %% [markdown]
# # XML CHANGER

# %%
def xml_changer():
    path = "../../custom/train"
    for xml_file in glob.glob(path + '/*.xml'):
            tree = ET.parse(xml_file)
            root = tree.getroot()
            #print(root.findall('_object'))
            for member in root.findall('_object'):
                if(root.find('filename').text == 'li_195.jpg'):
                    member[4][0].text = '0.00000313533335'
                #member[0].text = 'line'
                #newvalue = root.find('filename').text+'.jpg'
                #root.find('filename').text = newvalue
            tree.write(xml_file)
#xml_changer()

# %% [markdown]
# # Inspect tfRecord

# %%
link_t = "../../custom/train.record"
raw_dataset = tf.data.TFRecordDataset(link_t)

for raw_record in raw_dataset.take(1):
    example = tf.train.Example()
    example.ParseFromString(raw_record.numpy())
    print(example)

# %% [markdown]
# # Model and ckpt Info

# %%
c_root="./workspace/"
base_ws_dir=c_root+"SDL/models/my_resnet/"
model_dir=base_ws_dir
pipeline_config_path=base_ws_dir+"pipeline.config"
checkpoint_dir=base_ws_dir
output_directory_export=c_root+"SDL/exported-models/my_model"
trained_checkpoint_dir=base_ws_dir

#print(c_root, base_ws_dir, model_dir, pipeline_config_path, output_directory_export, trained_checkpoint_dir)

# %% [markdown]
# # Training

# %%
# !python model_main_tf2.py \
    --model_dir $model_dir \
    --pipeline_config_path $pipeline_config_path \
    --alsologtostderr


'''
#RAW
python model_main_tf2.py --model_dir=./workspace/SDL/models/my_resnet/ --pipeline_config_path=./workspace/SDL/models/my_resnet/pipeline.config --logtostderr
'''
# Out:
# 2021-03-22 17:22:10.940324: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-03-22 17:22:16.693360: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-03-22 17:22:16.697046: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-03-22 17:22:17.487860: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:02:00.0 name: Quadro M5000 computeCapability: 5.2
# coreClock: 1.038GHz coreCount: 16 deviceMemorySize: 7.93GiB deviceMemoryBandwidth: 196.99GiB/s
# 2021-03-22 17:22:17.488105: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-03-22 17:22:17.503683: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2021-03-22 17:22:17.504891: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2021-03-22 17:22:17.508092: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-03-22 17:22:17.509478: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-03-22 17:22:17.513411: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-03-22 17:22:17.519218: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2021-03-22 17:22:17.530257: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2021-03-22 17:22:17.574389: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2021-03-22 17:22:17.575248: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-03-22 17:22:17.579798: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:02:00.0 name: Quadro M5000 computeCapability: 5.2
# coreClock: 1.038GHz coreCount: 16 deviceMemorySize: 7.93GiB deviceMemoryBandwidth: 196.99GiB/s
# 2021-03-22 17:22:17.579833: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-03-22 17:22:17.579890: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2021-03-22 17:22:17.579918: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2021-03-22 17:22:17.579946: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-03-22 17:22:17.579973: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-03-22 17:22:17.580000: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-03-22 17:22:17.580028: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2021-03-22 17:22:17.580055: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2021-03-22 17:22:17.582501: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2021-03-22 17:22:17.582540: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-03-22 17:22:20.419139: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-03-22 17:22:20.419189: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2021-03-22 17:22:20.419206: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2021-03-22 17:22:20.423477: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 7456 MB memory) -> physical GPU (device: 0, name: Quadro M5000, pci bus id: 0000:02:00.0, compute capability: 5.2)
# 2021-03-22 17:22:20.445586: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# I0322 17:22:20.547993 140400572921664 mirrored_strategy.py:350] Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# INFO:tensorflow:Maybe overwriting train_steps: None
# I0322 17:22:20.578387 140400572921664 config_util.py:552] Maybe overwriting train_steps: None
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0322 17:22:20.580153 140400572921664 config_util.py:552] Maybe overwriting use_bfloat16: False
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0322 17:22:21.384018 140400572921664 cross_device_ops.py:565] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0322 17:22:21.386303 140400572921664 cross_device_ops.py:565] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0322 17:22:21.388075 140400572921664 cross_device_ops.py:565] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0322 17:22:21.388836 140400572921664 cross_device_ops.py:565] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0322 17:22:21.475661 140400572921664 cross_device_ops.py:565] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0322 17:22:21.478796 140400572921664 cross_device_ops.py:565] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0322 17:22:21.497242 140400572921664 cross_device_ops.py:565] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0322 17:22:21.498082 140400572921664 cross_device_ops.py:565] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0322 17:22:21.499421 140400572921664 cross_device_ops.py:565] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# I0322 17:22:21.500158 140400572921664 cross_device_ops.py:565] Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# 2021-03-22 17:22:23.306313: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2021-03-22 17:22:25.786180: W tensorflow/stream_executor/gpu/asm_compiler.cc:63] Running ptxas --version returned 256
# 2021-03-22 17:22:25.831384: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] Internal: ptxas exited with non-zero error code 256, output:
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 2021-03-22 17:22:26.351375: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# WARNING:tensorflow:From /home/mag/Abrar/miniconda3/lib/python3.7/site-packages/object_detection/model_lib_v2.py:540: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# W0322 17:22:47.111558 140400572921664 deprecation.py:339] From /home/mag/Abrar/miniconda3/lib/python3.7/site-packages/object_detection/model_lib_v2.py:540: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# Instructions for updating:
# rename to distribute_datasets_from_function
# INFO:tensorflow:Reading unweighted datasets: ['./workspace/SDL/annotations/train.record']
# I0322 17:22:47.119145 140400572921664 dataset_builder.py:163] Reading unweighted datasets: ['./workspace/SDL/annotations/train.record']
# INFO:tensorflow:Reading record datasets for input file: ['./workspace/SDL/annotations/train.record']
# I0322 17:22:47.119321 140400572921664 dataset_builder.py:80] Reading record datasets for input file: ['./workspace/SDL/annotations/train.record']
# INFO:tensorflow:Number of filenames to read: 1
# I0322 17:22:47.119398 140400572921664 dataset_builder.py:81] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W0322 17:22:47.119463 140400572921664 dataset_builder.py:88] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From /home/mag/Abrar/miniconda3/lib/python3.7/site-packages/object_detection/builders/dataset_builder.py:105: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.experimental_deterministic`.
# W0322 17:22:47.122459 140400572921664 deprecation.py:339] From /home/mag/Abrar/miniconda3/lib/python3.7/site-packages/object_detection/builders/dataset_builder.py:105: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.experimental_deterministic`.
# WARNING:tensorflow:From /home/mag/Abrar/miniconda3/lib/python3.7/site-packages/object_detection/builders/dataset_builder.py:237: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W0322 17:22:47.147648 140400572921664 deprecation.py:339] From /home/mag/Abrar/miniconda3/lib/python3.7/site-packages/object_detection/builders/dataset_builder.py:237: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:AutoGraph could not transform <bound method TfExampleDecoder.decode of <object_detection.data_decoders.tf_example_decoder.TfExampleDecoder object at 0x7fb0bc3d4210>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# W0322 17:22:47.196702 140400572921664 ag_logging.py:146] AutoGraph could not transform <bound method TfExampleDecoder.decode of <object_detection.data_decoders.tf_example_decoder.TfExampleDecoder object at 0x7fb0bc3d4210>> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function build at 0x7fb12c549ef0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# W0322 17:22:47.805402 140400572921664 ag_logging.py:146] AutoGraph could not transform <function build at 0x7fb12c549ef0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function build at 0x7fb12c7e9830> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# W0322 17:22:47.884553 140400572921664 ag_logging.py:146] AutoGraph could not transform <function build at 0x7fb12c7e9830> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function transform_input_data at 0x7fb12c4e9440> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# W0322 17:22:47.934894 140400572921664 ag_logging.py:146] AutoGraph could not transform <function transform_input_data at 0x7fb12c4e9440> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:From /home/mag/Abrar/miniconda3/lib/python3.7/site-packages/tensorflow/python/util/dispatch.py:201: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W0322 17:22:47.952988 140400572921664 deprecation.py:339] From /home/mag/Abrar/miniconda3/lib/python3.7/site-packages/tensorflow/python/util/dispatch.py:201: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From /home/mag/Abrar/miniconda3/lib/python3.7/site-packages/tensorflow/python/util/dispatch.py:201: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# W0322 17:22:48.057942 140400572921664 deprecation.py:339] From /home/mag/Abrar/miniconda3/lib/python3.7/site-packages/tensorflow/python/util/dispatch.py:201: sample_distorted_bounding_box (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# `seed2` arg is deprecated.Use sample_distorted_bounding_box_v2 instead.
# WARNING:tensorflow:From /home/mag/Abrar/miniconda3/lib/python3.7/site-packages/object_detection/inputs.py:284: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0322 17:22:48.128141 140400572921664 deprecation.py:339] From /home/mag/Abrar/miniconda3/lib/python3.7/site-packages/object_detection/inputs.py:284: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# WARNING:tensorflow:AutoGraph could not transform <function pad_input_data_to_static_shapes at 0x7fb12c4e94d0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# W0322 17:22:48.525759 140400572921664 ag_logging.py:146] AutoGraph could not transform <function pad_input_data_to_static_shapes at 0x7fb12c4e94d0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function _get_features_dict at 0x7fb12c4e9710> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# W0322 17:22:48.827049 140400572921664 ag_logging.py:146] AutoGraph could not transform <function _get_features_dict at 0x7fb12c4e9710> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function _get_labels_dict at 0x7fb12c4e95f0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# W0322 17:22:48.881044 140400572921664 ag_logging.py:146] AutoGraph could not transform <function _get_labels_dict at 0x7fb12c4e95f0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 2021-03-22 17:22:49.051678: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2021-03-22 17:22:49.081530: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2400085000 Hz
# WARNING:tensorflow:AutoGraph could not transform <function call_for_each_replica at 0x7fb1492b15f0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# W0322 17:22:50.385713 140400572921664 ag_logging.py:146] AutoGraph could not transform <function call_for_each_replica at 0x7fb1492b15f0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# /home/mag/Abrar/miniconda3/lib/python3.7/site-packages/tensorflow/python/keras/backend.py:434: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn('`tf.keras.backend.set_learning_phase` is deprecated and '
# WARNING:tensorflow:AutoGraph could not transform <function unstack_batch at 0x7fb12c4ffd40> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# W0322 17:22:50.444115 140391433086720 ag_logging.py:146] AutoGraph could not transform <function unstack_batch at 0x7fb12c4ffd40> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function _compute_losses_and_predictions_dicts at 0x7fb13b0c9b00> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# W0322 17:22
# I0322 19:35:42.404595 140400572921664 model_lib_v2.py:670] Step 31900 per-step time 0.595s loss=24.130
# INFO:tensorflow:Step 32000 per-step time 0.594s loss=22.789
# I0322 19:36:42.327319 140400572921664 model_lib_v2.py:670] Step 32000 per-step time 0.594s loss=22.789
# INFO:tensorflow:Step 32100 per-step time 0.610s loss=23.082
# I0322 19:37:43.193578 140400572921664 model_lib_v2.py:670] Step 32100 per-step time 0.610s loss=23.082
# INFO:tensorflow:Step 32200 per-step time 0.609s loss=23.051
# I0322 19:38:43.290325 140400572921664 model_lib_v2.py:670] Step 32200 per-step time 0.609s loss=23.051
# INFO:tensorflow:Step 32300 per-step time 0.608s loss=23.086
# I0322 19:39:43.200991 140400572921664 model_lib_v2.py:670] Step 32300 per-step time 0.608s loss=23.086
# INFO:tensorflow:Step 32400 per-step time 0.609s loss=22.572
# I0322 19:40:43.277696 140400572921664 model_lib_v2.py:670] Step 32400 per-step time 0.609s loss=22.572
# INFO:tensorflow:Step 32500 per-step time 0.599s loss=25.255
# I0322 19:41:43.290795 140400572921664 model_lib_v2.py:670] Step 32500 per-step time 0.599s loss=25.255
# INFO:tensorflow:Step 32600 per-step time 0.588s loss=23.012
# I0322 19:42:43.352874 140400572921664 model_lib_v2.py:670] Step 32600 per-step time 0.588s loss=23.012
# INFO:tensorflow:Step 32700 per-step time 0.594s loss=24.044
# I0322 19:43:43.390682 140400572921664 model_lib_v2.py:670] Step 32700 per-step time 0.594s loss=24.044
# INFO:tensorflow:Step 32800 per-step time 0.598s loss=24.639
# I0322 19:44:43.279067 140400572921664 model_lib_v2.py:670] Step 32800 per-step time 0.598s loss=24.639
# INFO:tensorflow:Step 32900 per-step time 0.616s loss=23.185
# I0322 19:45:43.208236 140400572921664 model_lib_v2.py:670] Step 32900 per-step time 0.616s loss=23.185
# INFO:tensorflow:Step 33000 per-step time 0.595s loss=22.276
# I0322 19:46:43.157787 140400572921664 model_lib_v2.py:670] Step 33000 per-step time 0.595s loss=22.276
# INFO:tensorflow:Step 33100 per-step time 0.599s loss=22.367
# I0322 19:47:44.024079 140400572921664 model_lib_v2.py:670] Step 33100 per-step time 0.599s loss=22.367
# INFO:tensorflow:Step 33200 per-step time 0.590s loss=22.168
# I0322 19:48:44.147930 140400572921664 model_lib_v2.py:670] Step 33200 per-step time 0.590s loss=22.168
# INFO:tensorflow:Step 33300 per-step time 0.597s loss=24.906
# I0322 19:49:44.288715 140400572921664 model_lib_v2.py:670] Step 33300 per-step time 0.597s loss=24.906
# INFO:tensorflow:Step 33400 per-step time 0.593s loss=22.143
# I0322 19:50:44.214761 140400572921664 model_lib_v2.py:670] Step 33400 per-step time 0.593s loss=22.143
# INFO:tensorflow:Step 33500 per-step time 0.602s loss=24.089
# I0322 19:51:44.189995 140400572921664 model_lib_v2.py:670] Step 33500 per-step time 0.602s loss=24.089
# INFO:tensorflow:Step 33600 per-step time 0.591s loss=22.507
# I0322 19:52:44.288368 140400572921664 model_lib_v2.py:670] Step 33600 per-step time 0.591s loss=22.507
# INFO:tensorflow:Step 33700 per-step time 0.607s loss=23.233
# I0322 19:53:44.382588 140400572921664 model_lib_v2.py:670] Step 33700 per-step time 0.607s loss=23.233
# INFO:tensorflow:Step 33800 per-step time 0.595s loss=23.295
# I0322 19:54:44.428641 140400572921664 model_lib_v2.py:670] Step 33800 per-step time 0.595s loss=23.295
# INFO:tensorflow:Step 33900 per-step time 0.592s loss=24.850
# I0322 19:55:44.470512 140400572921664 model_lib_v2.py:670] Step 33900 per-step time 0.592s loss=24.850
# INFO:tensorflow:Step 34000 per-step time 0.594s loss=22.562
# I0322 19:56:44.489102 140400572921664 model_lib_v2.py:670] Step 34000 per-step time 0.594s loss=22.562
# INFO:tensorflow:Step 34100 per-step time 0.600s loss=23.386
# I0322 19:57:45.377854 140400572921664 model_lib_v2.py:670] Step 34100 per-step time 0.600s loss=23.386
# INFO:tensorflow:Step 34200 per-step time 0.613s loss=23.854
# I0322 19:58:45.366180 140400572921664 model_lib_v2.py:670] Step 34200 per-step time 0.613s loss=23.854
# INFO:tensorflow:Step 34300 per-step time 0.590s loss=23.898
# I0322 19:59:45.775294 140400572921664 model_lib_v2.py:670] Step 34300 per-step time 0.590s loss=23.898
# INFO:tensorflow:Step 34400 per-step time 0.598s loss=23.094
# I0322 20:00:45.693243 140400572921664 model_lib_v2.py:670] Step 34400 per-step time 0.598s loss=23.094
# INFO:tensorflow:Step 34500 per-step time 0.608s loss=24.348
# I0322 20:01:45.512581 140400572921664 model_lib_v2.py:670] Step 34500 per-step time 0.608s loss=24.348
# INFO:tensorflow:Step 34600 per-step time 0.597s loss=23.936
# I0322 20:02:45.599943 140400572921664 model_lib_v2.py:670] Step 34600 per-step time 0.597s loss=23.936
# INFO:tensorflow:Step 34700 per-step time 0.597s loss=25.012
# I0322 20:03:45.663735 140400572921664 model_lib_v2.py:670] Step 34700 per-step time 0.597s loss=25.012
# INFO:tensorflow:Step 34800 per-step time 0.621s loss=23.728
# I0322 20:04:45.902668 140400572921664 model_lib_v2.py:670] Step 34800 per-step time 0.621s loss=23.728
# INFO:tensorflow:Step 34900 per-step time 0.613s loss=23.549
# I0322 20:05:46.228542 140400572921664 model_lib_v2.py:670] Step 34900 per-step time 0.613s loss=23.549
# INFO:tensorflow:Step 35000 per-step time 0.606s loss=22.784
# I0322 20:06:46.306415 140400572921664 model_lib_v2.py:670] Step 35000 per-step time 0.606s loss=22.784
# INFO:tensorflow:Step 35100 per-step time 0.592s loss=24.966
# I0322 20:07:47.155526 140400572921664 model_lib_v2.py:670] Step 35100 per-step time 0.592s loss=24.966
# INFO:tensorflow:Step 35200 per-step time 0.596s loss=21.818
# I0322 20:08:47.189947 140400572921664 model_lib_v2.py:670] Step 35200 per-step time 0.596s loss=21.818
# INFO:tensorflow:Step 35300 per-step time 0.598s loss=24.767
# I0322 20:09:47.366089 140400572921664 model_lib_v2.py:670] Step 35300 per-step time 0.598s loss=24.767
# INFO:tensorflow:Step 35400 per-step time 0.598s loss=21.916
# I0322 20:10:47.460716 140400572921664 model_lib_v2.py:670] Step 35400 per-step time 0.598s loss=21.916
# INFO:tensorflow:Step 35500 per-step time 0.595s loss=22.674
# I0322 20:11:47.443961 140400572921664 model_lib_v2.py:670] Step 35500 per-step time 0.595s loss=22.674
# INFO:tensorflow:Step 35600 per-step time 0.598s loss=23.515
# I0322 20:12:47.478005 140400572921664 model_lib_v2.py:670] Step 35600 per-step time 0.598s loss=23.515
# INFO:tensorflow:Step 35700 per-step time 0.616s loss=24.305
# I0322 20:13:47.544579 140400572921664 model_lib_v2.py:670] Step 35700 per-step time 0.616s loss=24.305
# INFO:tensorflow:Step 35800 per-step time 0.588s loss=22.558
# I0322 20:14:47.613107 140400572921664 model_lib_v2.py:670] Step 35800 per-step time 0.588s loss=22.558
# INFO:tensorflow:Step 35900 per-step time 0.586s loss=23.257
# I0322 20:15:47.861940 140400572921664 model_lib_v2.py:670] Step 35900 per-step time 0.586s loss=23.257
# INFO:tensorflow:Step 36000 per-step time 0.590s loss=23.335
# I0322 20:16:47.934910 140400572921664 model_lib_v2.py:670] Step 36000 per-step time 0.590s loss=23.335
# INFO:tensorflow:Step 36100 per-step time 0.600s loss=23.728
# I0322 20:17:48.878454 140400572921664 model_lib_v2.py:670] Step 36100 per-step time 0.600s loss=23.728
# INFO:tensorflow:Step 36200 per-step time 0.591s loss=22.344
# I0322 20:18:48.798015 140400572921664 model_lib_v2.py:670] Step 36200 per-step time 0.591s loss=22.344
# INFO:tensorflow:Step 36300 per-step time 0.595s loss=23.630
# I0322 20:19:48.717082 140400572921664 model_lib_v2.py:670] Step 36300 per-step time 0.595s loss=23.630
# INFO:tensorflow:Step 36400 per-step time 0.605s loss=23.224
# I0322 20:20:48.557723 140400572921664 model_lib_v2.py:670] Step 36400 per-step time 0.605s loss=23.224
# INFO:tensorflow:Step 36500 per-step time 0.593s loss=23.235
# I0322 20:21:49.179306 140400572921664 model_lib_v2.py:670] Step 36500 per-step time 0.593s loss=23.235
# INFO:tensorflow:Step 36600 per-step time 0.594s loss=23.903
# I0322 20:22:49.323075 140400572921664 model_lib_v2.py:670] Step 36600 per-step time 0.594s loss=23.903
# INFO:tensorflow:Step 36700 per-step time 0.595s loss=23.644
# I0322 20:23:49.243437 140400572921664 model_lib_v2.py:670] Step 36700 per-step time 0.595s loss=23.644
# INFO:tensorflow:Step 36800 per-step time 0.603s loss=22.808
# I0322 20:24:48.989557 140400572921664 model_lib_v2.py:670] Step 36800 per-step time 0.603s loss=22.808
# INFO:tensorflow:Step 36900 per-step time 0.605s loss=23.685
# I0322 20:25:48.989891 140400572921664 model_lib_v2.py:670] Step 36900 per-step time 0.605s loss=23.685
# INFO:tensorflow:Step 37000 per-step time 0.596s loss=23.270
# I0322 20:26:49.012767 140400572921664 model_lib_v2.py:670] Step 37000 per-step time 0.596s loss=23.270
# INFO:tensorflow:Step 37100 per-step time 0.596s loss=22.490
# I0322 20:27:49.901519 140400572921664 model_lib_v2.py:670] Step 37100 per-step time 0.596s loss=22.490
# INFO:tensorflow:Step 37200 per-step time 0.620s loss=24.468
# I0322 20:28:49.760663 140400572921664 model_lib_v2.py:670] Step 37200 per-step time 0.620s loss=24.468
# INFO:tensorflow:Step 37300 per-step time 0.592s loss=23.491
# I0322 20:29:49.576112 140400572921664 model_lib_v2.py:670] Step 37300 per-step time 0.592s loss=23.491
# INFO:tensorflow:Step 37400 per-step time 0.595s loss=24.041
# I0322 20:30:49.298938 140400572921664 model_lib_v2.py:670] Step 37400 per-step time 0.595s loss=24.041
# INFO:tensorflow:Step 37500 per-step time 0.612s loss=24.130
# I0322 20:31:49.431067 140400572921664 model_lib_v2.py:670] Step 37500 per-step time 0.612s loss=24.130
# INFO:tensorflow:Step 37600 per-step time 0.599s loss=23.926
# I0322 20:32:49.387546 140400572921664 model_lib_v2.py:670] Step 37600 per-step time 0.599s loss=23.926
# INFO:tensorflow:Step 37700 per-step time 0.594s loss=24.419
# I0322 20:33:49.097231 140400572921664 model_lib_v2.py:670] Step 37700 per-step time 0.594s loss=24.419
# INFO:tensorflow:Step 37800 per-step time 0.590s loss=22.398
# I0322 20:34:48.822518 140400572921664 model_lib_v2.py:670] Step 37800 per-step time 0.590s loss=22.398
# INFO:tensorflow:Step 37900 per-step time 0.593s loss=23.845
# I0322 20:35:48.497843 140400572921664 model_lib_v2.py:670] Step 37900 per-step time 0.593s loss=23.845
# INFO:tensorflow:Step 38000 per-step time 0.593s loss=22.524
# I0322 20:36:48.246565 140400572921664 model_lib_v2.py:670] Step 38000 per-step time 0.593s loss=22.524
# INFO:tensorflow:Step 38100 per-step time 0.595s loss=23.036
# I0322 20:37:48.572202 140400572921664 model_lib_v2.py:670] Step 38100 per-step time 0.595s loss=23.036
# INFO:tensorflow:Step 38200 per-step time 0.592s loss=23.180
# I0322 20:38:48.303383 140400572921664 model_lib_v2.py:670] Step 38200 per-step time 0.592s loss=23.180
# INFO:tensorflow:Step 38300 per-step time 0.595s loss=24.119
# I0322 20:39:48.102103 140400572921664 model_lib_v2.py:670] Step 38300 per-step time 0.595s loss=24.119
# INFO:tensorflow:Step 38400 per-step time 0.594s loss=23.774
# I0322 20:40:47.852626 140400572921664 model_lib_v2.py:670] Step 38400 per-step time 0.594s loss=23.774
# INFO:tensorflow:Step 38500 per-step time 0.599s loss=22.073
# I0322 20:41:47.626305 140400572921664 model_lib_v2.py:670] Step 38500 per-step time 0.599s loss=22.073
# INFO:tensorflow:Step 38600 per-step time 0.595s loss=23.057
# I0322 20:42:47.440032 140400572921664 model_lib_v2.py:670] Step 38600 per-step time 0.595s loss=23.057
# INFO:tensorflow:Step 38700 per-step time 0.597s loss=22.791
# I0322 20:43:47.516113 140400572921664 model_lib_v2.py:670] Step 38700 per-step time 0.597s loss=22.791
# INFO:tensorflow:Step 38800 per-step time 0.594s loss=22.429
# I0322 20:44:47.423844 140400572921664 model_lib_v2.py:670] Step 38800 per-step time 0.594s loss=22.429
# INFO:tensorflow:Step 38900 per-step time 0.594s loss=23.314
# I0322 20:45:47.263140 140400572921664 model_lib_v2.py:670] Step 38900 per-step time 0.594s loss=23.314
# INFO:tensorflow:Step 39000 per-step time 0.601s loss=22.275
# I0322 20:46:47.231705 140400572921664 model_lib_v2.py:670] Step 39000 per-step time 0.601s loss=22.275
# INFO:tensorflow:Step 39100 per-step time 0.602s loss=23.547
# I0322 20:47:47.727438 140400572921664 model_lib_v2.py:670] Step 39100 per-step time 0.602s loss=23.547
# INFO:tensorflow:Step 39200 per-step time 0.598s loss=24.289
# I0322 20:48:47.566884 140400572921664 model_lib_v2.py:670] Step 39200 per-step time 0.598s loss=24.289
# INFO:tensorflow:Step 39300 per-step time 0.590s loss=22.507
# I0322 20:49:47.595239 140400572921664 model_lib_v2.py:670] Step 39300 per-step time 0.590s loss=22.507
# INFO:tensorflow:Step 39400 per-step time 0.592s loss=23.295
# I0322 20:50:47.479681 140400572921664 model_lib_v2.py:670] Step 39400 per-step time 0.592s loss=23.295
# INFO:tensorflow:Step 39500 per-step time 0.588s loss=22.476
# I0322 20:51:47.324910 140400572921664 model_lib_v2.py:670] Step 39500 per-step time 0.588s loss=22.476
# INFO:tensorflow:Step 39600 per-step time 0.615s loss=22.852
# I0322 20:52:47.153255 140400572921664 model_lib_v2.py:670] Step 39600 per-step time 0.615s loss=22.852
# INFO:tensorflow:Step 39700 per-step time 0.593s loss=22.868
# I0322 20:53:46.926132 140400572921664 model_lib_v2.py:670] Step 39700 per-step time 0.593s loss=22.868
# INFO:tensorflow:Step 39800 per-step time 0.596s loss=21.745
# I0322 20:54:46.805912 140400572921664 model_lib_v2.py:670] Step 39800 per-step time 0.596s loss=21.745
# INFO:tensorflow:Step 39900 per-step time 0.595s loss=22.191
# I0322 20:55:46.639649 140400572921664 model_lib_v2.py:670] Step 39900 per-step time 0.595s loss=22.191
# INFO:tensorflow:Step 40000 per-step time 0.604s loss=23.057
# I0322 20:56:46.481378 140400572921664 model_lib_v2.py:670] Step 40000 per-step time 0.604s loss=23.057
# '\n#RAW\npython model_main_tf2.py --model_dir=./workspace/SDL/models/my_resnet/ --pipeline_config_path=./workspace/SDL/models/my_resnet/pipeline.config --logtostderr\n'

# %% [markdown]
# # Evaluation

# %%
# !python model_main_tf2.py \
    --model_dir $model_dir \
    --pipeline_config_path $pipeline_config_path \
    --checkpoint_dir $checkpoint_dir
# Out:
# 2021-03-20 18:31:47.939166: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# WARNING:tensorflow:Forced number of epochs for all eval validations to be 1.
# W0320 18:31:50.783129 140536574572352 model_lib_v2.py:1050] Forced number of epochs for all eval validations to be 1.
# INFO:tensorflow:Maybe overwriting sample_1_of_n_eval_examples: None
# I0320 18:31:50.783329 140536574572352 config_util.py:552] Maybe overwriting sample_1_of_n_eval_examples: None
# INFO:tensorflow:Maybe overwriting use_bfloat16: False
# I0320 18:31:50.783401 140536574572352 config_util.py:552] Maybe overwriting use_bfloat16: False
# INFO:tensorflow:Maybe overwriting eval_num_epochs: 1
# I0320 18:31:50.783471 140536574572352 config_util.py:552] Maybe overwriting eval_num_epochs: 1
# WARNING:tensorflow:Expected number of evaluation epochs is 1, but instead encountered `eval_on_train_input_config.num_epochs` = 0. Overwriting `num_epochs` to 1.
# W0320 18:31:50.783558 140536574572352 model_lib_v2.py:1071] Expected number of evaluation epochs is 1, but instead encountered `eval_on_train_input_config.num_epochs` = 0. Overwriting `num_epochs` to 1.
# 2021-03-20 18:31:50.790228: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-03-20 18:31:50.791348: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-03-20 18:31:50.807312: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:02:00.0 name: Quadro M5000 computeCapability: 5.2
# coreClock: 1.038GHz coreCount: 16 deviceMemorySize: 7.93GiB deviceMemoryBandwidth: 196.99GiB/s
# 2021-03-20 18:31:50.807348: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-03-20 18:31:50.808963: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2021-03-20 18:31:50.809013: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2021-03-20 18:31:50.810515: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-03-20 18:31:50.810794: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-03-20 18:31:50.812458: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-03-20 18:31:50.813466: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2021-03-20 18:31:50.817046: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2021-03-20 18:31:50.819197: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2021-03-20 18:31:50.819499: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-03-20 18:31:50.823495: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:02:00.0 name: Quadro M5000 computeCapability: 5.2
# coreClock: 1.038GHz coreCount: 16 deviceMemorySize: 7.93GiB deviceMemoryBandwidth: 196.99GiB/s
# 2021-03-20 18:31:50.823545: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-03-20 18:31:50.823594: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2021-03-20 18:31:50.823630: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2021-03-20 18:31:50.823664: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-03-20 18:31:50.823697: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-03-20 18:31:50.823731: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-03-20 18:31:50.823773: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2021-03-20 18:31:50.823807: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2021-03-20 18:31:50.827025: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2021-03-20 18:31:50.827095: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-03-20 18:31:51.772067: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-03-20 18:31:51.772131: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2021-03-20 18:31:51.772151: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2021-03-20 18:31:51.777847: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 7456 MB memory) -> physical GPU (device: 0, name: Quadro M5000, pci bus id: 0000:02:00.0, compute capability: 5.2)
# 2021-03-20 18:31:51.786298: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-03-20 18:31:52.901963: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2021-03-20 18:31:53.985634: W tensorflow/stream_executor/gpu/asm_compiler.cc:63] Running ptxas --version returned 256
# 2021-03-20 18:31:54.042254: W tensorflow/stream_executor/gpu/redzone_allocator.cc:314] Internal: ptxas exited with non-zero error code 256, output:
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 2021-03-20 18:31:54.506444: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# INFO:tensorflow:Reading unweighted datasets: ['./workspace/SDL/annotations/test.record']
# I0320 18:32:16.284876 140536574572352 dataset_builder.py:163] Reading unweighted datasets: ['./workspace/SDL/annotations/test.record']
# INFO:tensorflow:Reading record datasets for input file: ['./workspace/SDL/annotations/test.record']
# I0320 18:32:16.285445 140536574572352 dataset_builder.py:80] Reading record datasets for input file: ['./workspace/SDL/annotations/test.record']
# INFO:tensorflow:Number of filenames to read: 1
# I0320 18:32:16.285526 140536574572352 dataset_builder.py:81] Number of filenames to read: 1
# WARNING:tensorflow:num_readers has been reduced to 1 to match input file shards.
# W0320 18:32:16.285596 140536574572352 dataset_builder.py:88] num_readers has been reduced to 1 to match input file shards.
# WARNING:tensorflow:From /home/mag/Abrar/miniconda3/lib/python3.7/site-packages/object_detection/builders/dataset_builder.py:105: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.experimental_deterministic`.
# W0320 18:32:16.286820 140536574572352 deprecation.py:339] From /home/mag/Abrar/miniconda3/lib/python3.7/site-packages/object_detection/builders/dataset_builder.py:105: parallel_interleave (from tensorflow.python.data.experimental.ops.interleave_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.interleave(map_func, cycle_length, block_length, num_parallel_calls=tf.data.AUTOTUNE)` instead. If sloppy execution is desired, use `tf.data.Options.experimental_deterministic`.
# WARNING:tensorflow:From /home/mag/Abrar/miniconda3/lib/python3.7/site-packages/object_detection/builders/dataset_builder.py:237: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# W0320 18:32:16.308597 140536574572352 deprecation.py:339] From /home/mag/Abrar/miniconda3/lib/python3.7/site-packages/object_detection/builders/dataset_builder.py:237: DatasetV1.map_with_legacy_function (from tensorflow.python.data.ops.dataset_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.data.Dataset.map()
# WARNING:tensorflow:From /home/mag/Abrar/miniconda3/lib/python3.7/site-packages/tensorflow/python/util/dispatch.py:201: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# W0320 18:32:20.656900 140536574572352 deprecation.py:339] From /home/mag/Abrar/miniconda3/lib/python3.7/site-packages/tensorflow/python/util/dispatch.py:201: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# WARNING:tensorflow:From /home/mag/Abrar/miniconda3/lib/python3.7/site-packages/object_detection/inputs.py:282: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0320 18:32:22.012840 140536574572352 deprecation.py:339] From /home/mag/Abrar/miniconda3/lib/python3.7/site-packages/object_detection/inputs.py:282: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# INFO:tensorflow:Waiting for new checkpoint at ./workspace/SDL/models/my_resnet/
# I0320 18:32:24.987841 140536574572352 checkpoint_utils.py:139] Waiting for new checkpoint at ./workspace/SDL/models/my_resnet/
# INFO:tensorflow:Found new checkpoint at ./workspace/SDL/models/my_resnet/ckpt-28
# I0320 18:32:24.989094 140536574572352 checkpoint_utils.py:148] Found new checkpoint at ./workspace/SDL/models/my_resnet/ckpt-28
# /home/mag/Abrar/miniconda3/lib/python3.7/site-packages/tensorflow/python/keras/backend.py:434: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn('`tf.keras.backend.set_learning_phase` is deprecated and '
# 2021-03-20 18:32:26.239318: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2021-03-20 18:32:26.258104: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2399960000 Hz
# WARNING:tensorflow:From /home/mag/Abrar/miniconda3/lib/python3.7/site-packages/object_detection/eval_util.py:929: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# W0320 18:32:53.163050 140536574572352 deprecation.py:339] From /home/mag/Abrar/miniconda3/lib/python3.7/site-packages/object_detection/eval_util.py:929: to_int64 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.
# INFO:tensorflow:Finished eval step 0
# I0320 18:32:53.172528 140536574572352 model_lib_v2.py:926] Finished eval step 0
# WARNING:tensorflow:From /home/mag/Abrar/miniconda3/lib/python3.7/site-packages/object_detection/utils/visualization_utils.py:617: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
#     (it is not differentiable, and manipulates numpy arrays). It drops the
#     stateful argument making all functions stateful.
#
# W0320 18:32:53.328640 140536574572352 deprecation.py:339] From /home/mag/Abrar/miniconda3/lib/python3.7/site-packages/object_detection/utils/visualization_utils.py:617: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, there are two
#     options available in V2.
#     - tf.py_function takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.
#     - tf.numpy_function maintains the semantics of the deprecated tf.py_func
#     (it is not differentiable, and manipulates numpy arrays). It drops the
#     stateful argument making all functions stateful.
#
# INFO:tensorflow:Performing evaluation on 50 images.
# I0320 18:32:58.677779 140536574572352 coco_evaluation.py:293] Performing evaluation on 50 images.
# creating index...
# index created!
# INFO:tensorflow:Loading and preparing annotation results...
# I0320 18:32:58.685356 140536574572352 coco_tools.py:116] Loading and preparing annotation results...
# INFO:tensorflow:DONE (t=0.01s)
# I0320 18:32:58.695045 140536574572352 coco_tools.py:138] DONE (t=0.01s)
# creating index...
# index created!
# Running per image evaluation...
# Evaluate annotation type *bbox*
# DONE (t=0.34s).
# Accumulating evaluation results...
# DONE (t=0.02s).
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = -1.000
# INFO:tensorflow:Eval metrics at step 25000
# I0320 18:32:59.072965 140536574572352 model_lib_v2.py:975] Eval metrics at step 25000
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP: 0.000000
# I0320 18:32:59.074794 140536574572352 model_lib_v2.py:978] 	+ DetectionBoxes_Precision/mAP: 0.000000
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP@.50IOU: 0.000000
# I0320 18:32:59.075681 140536574572352 model_lib_v2.py:978] 	+ DetectionBoxes_Precision/mAP@.50IOU: 0.000000
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP@.75IOU: 0.000000
# I0320 18:32:59.076569 140536574572352 model_lib_v2.py:978] 	+ DetectionBoxes_Precision/mAP@.75IOU: 0.000000
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (small): 0.000000
# I0320 18:32:59.077446 140536574572352 model_lib_v2.py:978] 	+ DetectionBoxes_Precision/mAP (small): 0.000000
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (medium): -1.000000
# I0320 18:32:59.078366 140536574572352 model_lib_v2.py:978] 	+ DetectionBoxes_Precision/mAP (medium): -1.000000
# INFO:tensorflow:	+ DetectionBoxes_Precision/mAP (large): -1.000000
# I0320 18:32:59.079240 140536574572352 model_lib_v2.py:978] 	+ DetectionBoxes_Precision/mAP (large): -1.000000
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@1: 0.000000
# I0320 18:32:59.080106 140536574572352 model_lib_v2.py:978] 	+ DetectionBoxes_Recall/AR@1: 0.000000
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@10: 0.000000
# I0320 18:32:59.080977 140536574572352 model_lib_v2.py:978] 	+ DetectionBoxes_Recall/AR@10: 0.000000
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100: 0.000000
# I0320 18:32:59.081848 140536574572352 model_lib_v2.py:978] 	+ DetectionBoxes_Recall/AR@100: 0.000000
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (small): 0.000000
# I0320 18:32:59.082758 140536574572352 model_lib_v2.py:978] 	+ DetectionBoxes_Recall/AR@100 (small): 0.000000
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (medium): -1.000000
# I0320 18:32:59.083633 140536574572352 model_lib_v2.py:978] 	+ DetectionBoxes_Recall/AR@100 (medium): -1.000000
# INFO:tensorflow:	+ DetectionBoxes_Recall/AR@100 (large): -1.000000
# I0320 18:32:59.084529 140536574572352 model_lib_v2.py:978] 	+ DetectionBoxes_Recall/AR@100 (large): -1.000000
# INFO:tensorflow:	+ Loss/localization_loss: 1.831275
# I0320 18:32:59.085361 140536574572352 model_lib_v2.py:978] 	+ Loss/localization_loss: 1.831275
# INFO:tensorflow:	+ Loss/classification_loss: 0.146046
# I0320 18:32:59.086245 140536574572352 model_lib_v2.py:978] 	+ Loss/classification_loss: 0.146046
# INFO:tensorflow:	+ Loss/regularization_loss: 81.472031
# I0320 18:32:59.087069 140536574572352 model_lib_v2.py:978] 	+ Loss/regularization_loss: 81.472031
# INFO:tensorflow:	+ Loss/total_loss: 83.449356
# I0320 18:32:59.087884 140536574572352 model_lib_v2.py:978] 	+ Loss/total_loss: 83.449356
# ^C
# Traceback (most recent call last):
#   File "model_main_tf2.py", line 115, in <module>
#     tf.compat.v1.app.run()
#   File "/home/mag/Abrar/miniconda3/lib/python3.7/site-packages/tensorflow/python/platform/app.py", line 40, in run
#     _run(main=main, argv=argv, flags_parser=_parse_flags_tolerate_undef)
#   File "/home/mag/Abrar/miniconda3/lib/python3.7/site-packages/absl/app.py", line 303, in run
#     _run_main(main, args)
#   File "/home/mag/Abrar/miniconda3/lib/python3.7/site-packages/absl/app.py", line 251, in _run_main
#     sys.exit(main(argv))
#   File "model_main_tf2.py", line 90, in main
#     wait_interval=300, timeout=FLAGS.eval_timeout)
#   File "/home/mag/Abrar/miniconda3/lib/python3.7/site-packages/object_detection/model_lib_v2.py", line 1104, in eval_continuously
#     checkpoint_dir, timeout=timeout, min_interval_secs=wait_interval):
#   File "/home/mag/Abrar/miniconda3/lib/python3.7/site-packages/tensorflow/python/training/checkpoint_utils.py", line 215, in checkpoints_iterator
#     time.sleep(time_to_next_eval)
# KeyboardInterrupt

# %% [markdown]
# # Export Model

# %%
# !python ./exporter_main_v2.py \
    --input_type=image_tensor \
    --pipeline_config_path=$pipeline_config_path \
    --trained_checkpoint_dir=$trained_checkpoint_dir \
    --output_directory=$output_directory_export
# Out:
# 2021-03-20 18:37:21.409343: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-03-20 18:37:23.598825: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-03-20 18:37:23.600519: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-03-20 18:37:23.659893: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:02:00.0 name: Quadro M5000 computeCapability: 5.2
# coreClock: 1.038GHz coreCount: 16 deviceMemorySize: 7.93GiB deviceMemoryBandwidth: 196.99GiB/s
# 2021-03-20 18:37:23.659982: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-03-20 18:37:23.665482: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2021-03-20 18:37:23.665578: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2021-03-20 18:37:23.668776: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-03-20 18:37:23.669301: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-03-20 18:37:23.672944: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-03-20 18:37:23.675120: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2021-03-20 18:37:23.683226: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2021-03-20 18:37:23.692880: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2021-03-20 18:37:23.693396: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-03-20 18:37:23.697013: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:02:00.0 name: Quadro M5000 computeCapability: 5.2
# coreClock: 1.038GHz coreCount: 16 deviceMemorySize: 7.93GiB deviceMemoryBandwidth: 196.99GiB/s
# 2021-03-20 18:37:23.707722: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-03-20 18:37:23.707790: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.10
# 2021-03-20 18:37:23.707844: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.10
# 2021-03-20 18:37:23.707897: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-03-20 18:37:23.707948: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-03-20 18:37:23.708000: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-03-20 18:37:23.708051: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.10
# 2021-03-20 18:37:23.708102: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.7
# 2021-03-20 18:37:23.722018: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2021-03-20 18:37:23.722154: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1
# 2021-03-20 18:37:24.563368: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-03-20 18:37:24.563419: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2021-03-20 18:37:24.563427: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2021-03-20 18:37:24.566667: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 7456 MB memory) -> physical GPU (device: 0, name: Quadro M5000, pci bus id: 0000:02:00.0, compute capability: 5.2)
# 2021-03-20 18:37:24.567061: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# WARNING:tensorflow:From /home/mag/Abrar/miniconda3/lib/python3.7/site-packages/object_detection/exporter_lib_v2.py:106: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# W0320 18:37:24.871825 140623830337344 deprecation.py:604] From /home/mag/Abrar/miniconda3/lib/python3.7/site-packages/object_detection/exporter_lib_v2.py:106: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with back_prop=False is deprecated and will be removed in a future version.
# Instructions for updating:
# back_prop=False is deprecated. Consider using tf.stop_gradient instead.
# Instead of:
# results = tf.map_fn(fn, elems, back_prop=False)
# Use:
# results = tf.nest.map_structure(tf.stop_gradient, tf.map_fn(fn, elems))
# WARNING:tensorflow:Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x7fe52c1597d0>, because it is not built.
# W0320 18:37:42.587105 140623830337344 save_impl.py:78] Skipping full serialization of Keras layer <object_detection.meta_architectures.ssd_meta_arch.SSDMetaArch object at 0x7fe52c1597d0>, because it is not built.
# 2021-03-20 18:37:55.769689: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Unsupported signature for serialization: (([(<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce767910>, TensorSpec(shape=(None, 80, 80, 512), dtype=tf.float32, name='image_features/0/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce767e90>, TensorSpec(shape=(None, 40, 40, 1024), dtype=tf.float32, name='image_features/1/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce76e110>, TensorSpec(shape=(None, 20, 20, 2048), dtype=tf.float32, name='image_features/2/1'))], True), {}).
# I0320 18:38:05.852225 140623830337344 def_function.py:1170] Unsupported signature for serialization: (([(<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce767910>, TensorSpec(shape=(None, 80, 80, 512), dtype=tf.float32, name='image_features/0/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce767e90>, TensorSpec(shape=(None, 40, 40, 1024), dtype=tf.float32, name='image_features/1/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce76e110>, TensorSpec(shape=(None, 20, 20, 2048), dtype=tf.float32, name='image_features/2/1'))], True), {}).
# INFO:tensorflow:Unsupported signature for serialization: (([(<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce77d5d0>, TensorSpec(shape=(None, 80, 80, 512), dtype=tf.float32, name='image_features/0/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce77d610>, TensorSpec(shape=(None, 40, 40, 1024), dtype=tf.float32, name='image_features/1/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce77d7d0>, TensorSpec(shape=(None, 20, 20, 2048), dtype=tf.float32, name='image_features/2/1'))], False), {}).
# I0320 18:38:05.852601 140623830337344 def_function.py:1170] Unsupported signature for serialization: (([(<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce77d5d0>, TensorSpec(shape=(None, 80, 80, 512), dtype=tf.float32, name='image_features/0/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce77d610>, TensorSpec(shape=(None, 40, 40, 1024), dtype=tf.float32, name='image_features/1/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce77d7d0>, TensorSpec(shape=(None, 20, 20, 2048), dtype=tf.float32, name='image_features/2/1'))], False), {}).
# INFO:tensorflow:Unsupported signature for serialization: (([(<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7fff50>, TensorSpec(shape=(None, 80, 80, 512), dtype=tf.float32, name='image_features/0/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7fa510>, TensorSpec(shape=(None, 40, 40, 1024), dtype=tf.float32, name='image_features/1/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7fa6d0>, TensorSpec(shape=(None, 20, 20, 2048), dtype=tf.float32, name='image_features/2/1'))], True), {}).
# I0320 18:38:05.852827 140623830337344 def_function.py:1170] Unsupported signature for serialization: (([(<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7fff50>, TensorSpec(shape=(None, 80, 80, 512), dtype=tf.float32, name='image_features/0/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7fa510>, TensorSpec(shape=(None, 40, 40, 1024), dtype=tf.float32, name='image_features/1/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7fa6d0>, TensorSpec(shape=(None, 20, 20, 2048), dtype=tf.float32, name='image_features/2/1'))], True), {}).
# INFO:tensorflow:Unsupported signature for serialization: (([(<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7aebd0>, TensorSpec(shape=(None, 80, 80, 512), dtype=tf.float32, name='image_features/0/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7aec50>, TensorSpec(shape=(None, 40, 40, 1024), dtype=tf.float32, name='image_features/1/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7b03d0>, TensorSpec(shape=(None, 20, 20, 2048), dtype=tf.float32, name='image_features/2/1'))], False), {}).
# I0320 18:38:05.853000 140623830337344 def_function.py:1170] Unsupported signature for serialization: (([(<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7aebd0>, TensorSpec(shape=(None, 80, 80, 512), dtype=tf.float32, name='image_features/0/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7aec50>, TensorSpec(shape=(None, 40, 40, 1024), dtype=tf.float32, name='image_features/1/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7b03d0>, TensorSpec(shape=(None, 20, 20, 2048), dtype=tf.float32, name='image_features/2/1'))], False), {}).
# INFO:tensorflow:Unsupported signature for serialization: (([(<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce767910>, TensorSpec(shape=(None, 80, 80, 512), dtype=tf.float32, name='image_features/0/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce767e90>, TensorSpec(shape=(None, 40, 40, 1024), dtype=tf.float32, name='image_features/1/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce76e110>, TensorSpec(shape=(None, 20, 20, 2048), dtype=tf.float32, name='image_features/2/1'))], True), {}).
# I0320 18:38:12.498791 140623830337344 def_function.py:1170] Unsupported signature for serialization: (([(<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce767910>, TensorSpec(shape=(None, 80, 80, 512), dtype=tf.float32, name='image_features/0/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce767e90>, TensorSpec(shape=(None, 40, 40, 1024), dtype=tf.float32, name='image_features/1/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce76e110>, TensorSpec(shape=(None, 20, 20, 2048), dtype=tf.float32, name='image_features/2/1'))], True), {}).
# INFO:tensorflow:Unsupported signature for serialization: (([(<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce77d5d0>, TensorSpec(shape=(None, 80, 80, 512), dtype=tf.float32, name='image_features/0/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce77d610>, TensorSpec(shape=(None, 40, 40, 1024), dtype=tf.float32, name='image_features/1/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce77d7d0>, TensorSpec(shape=(None, 20, 20, 2048), dtype=tf.float32, name='image_features/2/1'))], False), {}).
# I0320 18:38:12.499207 140623830337344 def_function.py:1170] Unsupported signature for serialization: (([(<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce77d5d0>, TensorSpec(shape=(None, 80, 80, 512), dtype=tf.float32, name='image_features/0/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce77d610>, TensorSpec(shape=(None, 40, 40, 1024), dtype=tf.float32, name='image_features/1/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce77d7d0>, TensorSpec(shape=(None, 20, 20, 2048), dtype=tf.float32, name='image_features/2/1'))], False), {}).
# INFO:tensorflow:Unsupported signature for serialization: (([(<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7fff50>, TensorSpec(shape=(None, 80, 80, 512), dtype=tf.float32, name='image_features/0/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7fa510>, TensorSpec(shape=(None, 40, 40, 1024), dtype=tf.float32, name='image_features/1/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7fa6d0>, TensorSpec(shape=(None, 20, 20, 2048), dtype=tf.float32, name='image_features/2/1'))], True), {}).
# I0320 18:38:12.499422 140623830337344 def_function.py:1170] Unsupported signature for serialization: (([(<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7fff50>, TensorSpec(shape=(None, 80, 80, 512), dtype=tf.float32, name='image_features/0/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7fa510>, TensorSpec(shape=(None, 40, 40, 1024), dtype=tf.float32, name='image_features/1/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7fa6d0>, TensorSpec(shape=(None, 20, 20, 2048), dtype=tf.float32, name='image_features/2/1'))], True), {}).
# INFO:tensorflow:Unsupported signature for serialization: (([(<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7aebd0>, TensorSpec(shape=(None, 80, 80, 512), dtype=tf.float32, name='image_features/0/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7aec50>, TensorSpec(shape=(None, 40, 40, 1024), dtype=tf.float32, name='image_features/1/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7b03d0>, TensorSpec(shape=(None, 20, 20, 2048), dtype=tf.float32, name='image_features/2/1'))], False), {}).
# I0320 18:38:12.499600 140623830337344 def_function.py:1170] Unsupported signature for serialization: (([(<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7aebd0>, TensorSpec(shape=(None, 80, 80, 512), dtype=tf.float32, name='image_features/0/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7aec50>, TensorSpec(shape=(None, 40, 40, 1024), dtype=tf.float32, name='image_features/1/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7b03d0>, TensorSpec(shape=(None, 20, 20, 2048), dtype=tf.float32, name='image_features/2/1'))], False), {}).
# INFO:tensorflow:Unsupported signature for serialization: (([(<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7fff50>, TensorSpec(shape=(None, 80, 80, 512), dtype=tf.float32, name='image_features/0/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7fa510>, TensorSpec(shape=(None, 40, 40, 1024), dtype=tf.float32, name='image_features/1/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7fa6d0>, TensorSpec(shape=(None, 20, 20, 2048), dtype=tf.float32, name='image_features/2/1'))], True), {}).
# I0320 18:38:12.499774 140623830337344 def_function.py:1170] Unsupported signature for serialization: (([(<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7fff50>, TensorSpec(shape=(None, 80, 80, 512), dtype=tf.float32, name='image_features/0/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7fa510>, TensorSpec(shape=(None, 40, 40, 1024), dtype=tf.float32, name='image_features/1/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7fa6d0>, TensorSpec(shape=(None, 20, 20, 2048), dtype=tf.float32, name='image_features/2/1'))], True), {}).
# INFO:tensorflow:Unsupported signature for serialization: (([(<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7aebd0>, TensorSpec(shape=(None, 80, 80, 512), dtype=tf.float32, name='image_features/0/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7aec50>, TensorSpec(shape=(None, 40, 40, 1024), dtype=tf.float32, name='image_features/1/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7b03d0>, TensorSpec(shape=(None, 20, 20, 2048), dtype=tf.float32, name='image_features/2/1'))], False), {}).
# I0320 18:38:12.499924 140623830337344 def_function.py:1170] Unsupported signature for serialization: (([(<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7aebd0>, TensorSpec(shape=(None, 80, 80, 512), dtype=tf.float32, name='image_features/0/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7aec50>, TensorSpec(shape=(None, 40, 40, 1024), dtype=tf.float32, name='image_features/1/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7b03d0>, TensorSpec(shape=(None, 20, 20, 2048), dtype=tf.float32, name='image_features/2/1'))], False), {}).
# W0320 18:38:18.440856 140623830337344 save.py:241] Found untraced functions such as WeightSharedConvolutionalBoxPredictor_layer_call_fn, WeightSharedConvolutionalBoxPredictor_layer_call_and_return_conditional_losses, WeightSharedConvolutionalBoxHead_layer_call_fn, WeightSharedConvolutionalBoxHead_layer_call_and_return_conditional_losses, WeightSharedConvolutionalBoxPredictor_layer_call_fn while saving (showing 5 of 315). These functions will not be directly callable after loading.
# INFO:tensorflow:Unsupported signature for serialization: (([(<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce767910>, TensorSpec(shape=(None, 80, 80, 512), dtype=tf.float32, name='image_features/0/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce767e90>, TensorSpec(shape=(None, 40, 40, 1024), dtype=tf.float32, name='image_features/1/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce76e110>, TensorSpec(shape=(None, 20, 20, 2048), dtype=tf.float32, name='image_features/2/1'))], True), {}).
# I0320 18:38:18.707447 140623830337344 def_function.py:1170] Unsupported signature for serialization: (([(<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce767910>, TensorSpec(shape=(None, 80, 80, 512), dtype=tf.float32, name='image_features/0/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce767e90>, TensorSpec(shape=(None, 40, 40, 1024), dtype=tf.float32, name='image_features/1/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce76e110>, TensorSpec(shape=(None, 20, 20, 2048), dtype=tf.float32, name='image_features/2/1'))], True), {}).
# INFO:tensorflow:Unsupported signature for serialization: (([(<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce77d5d0>, TensorSpec(shape=(None, 80, 80, 512), dtype=tf.float32, name='image_features/0/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce77d610>, TensorSpec(shape=(None, 40, 40, 1024), dtype=tf.float32, name='image_features/1/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce77d7d0>, TensorSpec(shape=(None, 20, 20, 2048), dtype=tf.float32, name='image_features/2/1'))], False), {}).
# I0320 18:38:18.707759 140623830337344 def_function.py:1170] Unsupported signature for serialization: (([(<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce77d5d0>, TensorSpec(shape=(None, 80, 80, 512), dtype=tf.float32, name='image_features/0/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce77d610>, TensorSpec(shape=(None, 40, 40, 1024), dtype=tf.float32, name='image_features/1/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce77d7d0>, TensorSpec(shape=(None, 20, 20, 2048), dtype=tf.float32, name='image_features/2/1'))], False), {}).
# INFO:tensorflow:Unsupported signature for serialization: (([(<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7fff50>, TensorSpec(shape=(None, 80, 80, 512), dtype=tf.float32, name='image_features/0/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7fa510>, TensorSpec(shape=(None, 40, 40, 1024), dtype=tf.float32, name='image_features/1/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7fa6d0>, TensorSpec(shape=(None, 20, 20, 2048), dtype=tf.float32, name='image_features/2/1'))], True), {}).
# I0320 18:38:18.707962 140623830337344 def_function.py:1170] Unsupported signature for serialization: (([(<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7fff50>, TensorSpec(shape=(None, 80, 80, 512), dtype=tf.float32, name='image_features/0/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7fa510>, TensorSpec(shape=(None, 40, 40, 1024), dtype=tf.float32, name='image_features/1/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7fa6d0>, TensorSpec(shape=(None, 20, 20, 2048), dtype=tf.float32, name='image_features/2/1'))], True), {}).
# INFO:tensorflow:Unsupported signature for serialization: (([(<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7aebd0>, TensorSpec(shape=(None, 80, 80, 512), dtype=tf.float32, name='image_features/0/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7aec50>, TensorSpec(shape=(None, 40, 40, 1024), dtype=tf.float32, name='image_features/1/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7b03d0>, TensorSpec(shape=(None, 20, 20, 2048), dtype=tf.float32, name='image_features/2/1'))], False), {}).
# I0320 18:38:18.708128 140623830337344 def_function.py:1170] Unsupported signature for serialization: (([(<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7aebd0>, TensorSpec(shape=(None, 80, 80, 512), dtype=tf.float32, name='image_features/0/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7aec50>, TensorSpec(shape=(None, 40, 40, 1024), dtype=tf.float32, name='image_features/1/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7b03d0>, TensorSpec(shape=(None, 20, 20, 2048), dtype=tf.float32, name='image_features/2/1'))], False), {}).
# INFO:tensorflow:Unsupported signature for serialization: (([(<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce767910>, TensorSpec(shape=(None, 80, 80, 512), dtype=tf.float32, name='image_features/0/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce767e90>, TensorSpec(shape=(None, 40, 40, 1024), dtype=tf.float32, name='image_features/1/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce76e110>, TensorSpec(shape=(None, 20, 20, 2048), dtype=tf.float32, name='image_features/2/1'))], True), {}).
# I0320 18:38:19.290627 140623830337344 def_function.py:1170] Unsupported signature for serialization: (([(<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce767910>, TensorSpec(shape=(None, 80, 80, 512), dtype=tf.float32, name='image_features/0/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce767e90>, TensorSpec(shape=(None, 40, 40, 1024), dtype=tf.float32, name='image_features/1/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce76e110>, TensorSpec(shape=(None, 20, 20, 2048), dtype=tf.float32, name='image_features/2/1'))], True), {}).
# INFO:tensorflow:Unsupported signature for serialization: (([(<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce77d5d0>, TensorSpec(shape=(None, 80, 80, 512), dtype=tf.float32, name='image_features/0/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce77d610>, TensorSpec(shape=(None, 40, 40, 1024), dtype=tf.float32, name='image_features/1/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce77d7d0>, TensorSpec(shape=(None, 20, 20, 2048), dtype=tf.float32, name='image_features/2/1'))], False), {}).
# I0320 18:38:19.290934 140623830337344 def_function.py:1170] Unsupported signature for serialization: (([(<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce77d5d0>, TensorSpec(shape=(None, 80, 80, 512), dtype=tf.float32, name='image_features/0/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce77d610>, TensorSpec(shape=(None, 40, 40, 1024), dtype=tf.float32, name='image_features/1/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce77d7d0>, TensorSpec(shape=(None, 20, 20, 2048), dtype=tf.float32, name='image_features/2/1'))], False), {}).
# INFO:tensorflow:Unsupported signature for serialization: (([(<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7fff50>, TensorSpec(shape=(None, 80, 80, 512), dtype=tf.float32, name='image_features/0/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7fa510>, TensorSpec(shape=(None, 40, 40, 1024), dtype=tf.float32, name='image_features/1/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7fa6d0>, TensorSpec(shape=(None, 20, 20, 2048), dtype=tf.float32, name='image_features/2/1'))], True), {}).
# I0320 18:38:19.291128 140623830337344 def_function.py:1170] Unsupported signature for serialization: (([(<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7fff50>, TensorSpec(shape=(None, 80, 80, 512), dtype=tf.float32, name='image_features/0/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7fa510>, TensorSpec(shape=(None, 40, 40, 1024), dtype=tf.float32, name='image_features/1/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7fa6d0>, TensorSpec(shape=(None, 20, 20, 2048), dtype=tf.float32, name='image_features/2/1'))], True), {}).
# INFO:tensorflow:Unsupported signature for serialization: (([(<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7aebd0>, TensorSpec(shape=(None, 80, 80, 512), dtype=tf.float32, name='image_features/0/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7aec50>, TensorSpec(shape=(None, 40, 40, 1024), dtype=tf.float32, name='image_features/1/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7b03d0>, TensorSpec(shape=(None, 20, 20, 2048), dtype=tf.float32, name='image_features/2/1'))], False), {}).
# I0320 18:38:19.291297 140623830337344 def_function.py:1170] Unsupported signature for serialization: (([(<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7aebd0>, TensorSpec(shape=(None, 80, 80, 512), dtype=tf.float32, name='image_features/0/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7aec50>, TensorSpec(shape=(None, 40, 40, 1024), dtype=tf.float32, name='image_features/1/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7b03d0>, TensorSpec(shape=(None, 20, 20, 2048), dtype=tf.float32, name='image_features/2/1'))], False), {}).
# INFO:tensorflow:Unsupported signature for serialization: (([(<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7fff50>, TensorSpec(shape=(None, 80, 80, 512), dtype=tf.float32, name='image_features/0/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7fa510>, TensorSpec(shape=(None, 40, 40, 1024), dtype=tf.float32, name='image_features/1/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7fa6d0>, TensorSpec(shape=(None, 20, 20, 2048), dtype=tf.float32, name='image_features/2/1'))], True), {}).
# I0320 18:38:19.291475 140623830337344 def_function.py:1170] Unsupported signature for serialization: (([(<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7fff50>, TensorSpec(shape=(None, 80, 80, 512), dtype=tf.float32, name='image_features/0/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7fa510>, TensorSpec(shape=(None, 40, 40, 1024), dtype=tf.float32, name='image_features/1/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7fa6d0>, TensorSpec(shape=(None, 20, 20, 2048), dtype=tf.float32, name='image_features/2/1'))], True), {}).
# INFO:tensorflow:Unsupported signature for serialization: (([(<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7aebd0>, TensorSpec(shape=(None, 80, 80, 512), dtype=tf.float32, name='image_features/0/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7aec50>, TensorSpec(shape=(None, 40, 40, 1024), dtype=tf.float32, name='image_features/1/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7b03d0>, TensorSpec(shape=(None, 20, 20, 2048), dtype=tf.float32, name='image_features/2/1'))], False), {}).
# I0320 18:38:19.291633 140623830337344 def_function.py:1170] Unsupported signature for serialization: (([(<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7aebd0>, TensorSpec(shape=(None, 80, 80, 512), dtype=tf.float32, name='image_features/0/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7aec50>, TensorSpec(shape=(None, 40, 40, 1024), dtype=tf.float32, name='image_features/1/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7b03d0>, TensorSpec(shape=(None, 20, 20, 2048), dtype=tf.float32, name='image_features/2/1'))], False), {}).
# W0320 18:38:20.352599 140623830337344 save.py:241] Found untraced functions such as WeightSharedConvolutionalBoxPredictor_layer_call_fn, WeightSharedConvolutionalBoxPredictor_layer_call_and_return_conditional_losses, WeightSharedConvolutionalBoxHead_layer_call_fn, WeightSharedConvolutionalBoxHead_layer_call_and_return_conditional_losses, WeightSharedConvolutionalBoxPredictor_layer_call_fn while saving (showing 5 of 315). These functions will not be directly callable after loading.
# INFO:tensorflow:Unsupported signature for serialization: (([(<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce767910>, TensorSpec(shape=(None, 80, 80, 512), dtype=tf.float32, name='image_features/0/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce767e90>, TensorSpec(shape=(None, 40, 40, 1024), dtype=tf.float32, name='image_features/1/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce76e110>, TensorSpec(shape=(None, 20, 20, 2048), dtype=tf.float32, name='image_features/2/1'))], True), {}).
# I0320 18:38:25.394076 140623830337344 def_function.py:1170] Unsupported signature for serialization: (([(<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce767910>, TensorSpec(shape=(None, 80, 80, 512), dtype=tf.float32, name='image_features/0/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce767e90>, TensorSpec(shape=(None, 40, 40, 1024), dtype=tf.float32, name='image_features/1/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce76e110>, TensorSpec(shape=(None, 20, 20, 2048), dtype=tf.float32, name='image_features/2/1'))], True), {}).
# INFO:tensorflow:Unsupported signature for serialization: (([(<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce77d5d0>, TensorSpec(shape=(None, 80, 80, 512), dtype=tf.float32, name='image_features/0/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce77d610>, TensorSpec(shape=(None, 40, 40, 1024), dtype=tf.float32, name='image_features/1/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce77d7d0>, TensorSpec(shape=(None, 20, 20, 2048), dtype=tf.float32, name='image_features/2/1'))], False), {}).
# I0320 18:38:25.394516 140623830337344 def_function.py:1170] Unsupported signature for serialization: (([(<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce77d5d0>, TensorSpec(shape=(None, 80, 80, 512), dtype=tf.float32, name='image_features/0/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce77d610>, TensorSpec(shape=(None, 40, 40, 1024), dtype=tf.float32, name='image_features/1/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce77d7d0>, TensorSpec(shape=(None, 20, 20, 2048), dtype=tf.float32, name='image_features/2/1'))], False), {}).
# INFO:tensorflow:Unsupported signature for serialization: (([(<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7fff50>, TensorSpec(shape=(None, 80, 80, 512), dtype=tf.float32, name='image_features/0/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7fa510>, TensorSpec(shape=(None, 40, 40, 1024), dtype=tf.float32, name='image_features/1/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7fa6d0>, TensorSpec(shape=(None, 20, 20, 2048), dtype=tf.float32, name='image_features/2/1'))], True), {}).
# I0320 18:38:25.394938 140623830337344 def_function.py:1170] Unsupported signature for serialization: (([(<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7fff50>, TensorSpec(shape=(None, 80, 80, 512), dtype=tf.float32, name='image_features/0/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7fa510>, TensorSpec(shape=(None, 40, 40, 1024), dtype=tf.float32, name='image_features/1/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7fa6d0>, TensorSpec(shape=(None, 20, 20, 2048), dtype=tf.float32, name='image_features/2/1'))], True), {}).
# INFO:tensorflow:Unsupported signature for serialization: (([(<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7aebd0>, TensorSpec(shape=(None, 80, 80, 512), dtype=tf.float32, name='image_features/0/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7aec50>, TensorSpec(shape=(None, 40, 40, 1024), dtype=tf.float32, name='image_features/1/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7b03d0>, TensorSpec(shape=(None, 20, 20, 2048), dtype=tf.float32, name='image_features/2/1'))], False), {}).
# I0320 18:38:25.395131 140623830337344 def_function.py:1170] Unsupported signature for serialization: (([(<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7aebd0>, TensorSpec(shape=(None, 80, 80, 512), dtype=tf.float32, name='image_features/0/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7aec50>, TensorSpec(shape=(None, 40, 40, 1024), dtype=tf.float32, name='image_features/1/1')), (<tensorflow.python.framework.func_graph.UnknownArgument object at 0x7fe3ce7b03d0>, TensorSpec(shape=(None, 20, 20, 2048), dtype=tf.float32, name='image_features/2/1'))], False), {}).
# INFO:tensorflow:Assets written to: ./workspace/SDL/exported-models/my_model/saved_model/assets
# I0320 18:38:26.802149 140623830337344 builder_impl.py:775] Assets written to: ./workspace/SDL/exported-models/my_model/saved_model/assets
# INFO:tensorflow:Writing pipeline config file to ./workspace/SDL/exported-models/my_model/pipeline.config
# I0320 18:38:27.669729 140623830337344 config_util.py:254] Writing pipeline config file to ./workspace/SDL/exported-models/my_model/pipeline.config
